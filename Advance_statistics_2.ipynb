# %% [markdown]
# Question 1: What is a random variable in probability theory?
#
#
# Answer:
#  A set of possible values from a random experiment.
# Example:- Tossing Coin:- Experiment is random,outcomes will be random.
# X(heads)=1
# X(tails)=0
# It helps us quantify outcomes of random processes.
# Types of Random variable
# 1.Discrete Random variable
# 2.Continuous random variable
#
# Question 2: What are the types of random variables?
#
#
# Answer:
# •	Discrete Random Variable
# •	Takes countable (finite or countably infinite) values.
# •	Typically used for outcomes you can list or enumerate.
# Examples:
# •	Number of heads in 10 coin tosses: 0,1,2,...,100, 1, 2, ..., 100,1,2,...,10
# •	Number of students in a class
# •	Rolling a die: 1,2,3,4,5,61, 2, 3, 4, 5, 61,2,3,4,5,6.
# 2. Continuous Random Variable
# •	Takes uncountably infinite values over an interval.
# •	  Used for measurements where precision can be infinitely fine.
# Examples:
# •	Height of a person
# •	Time taken to complete a task
# •	Temperature in a room
#
#
# Question 3: Explain the difference between discrete and continuous distributions.
#
#
# Answer:  1. Discrete Distribution
# •	Deals with discrete random variables (countable values).
# •	Probabilities are assigned to individual values.
# 🔹 Characteristics:
# •	Probability is given by a Probability Mass Function (PMF).
# •	The total probability is:
# ∑P(X=xi)=1
# •	Specific values can have non-zero probabilities.
# 🔹 Examples:
# •	Binomial distribution (e.g., number of heads in coin tosses)
# •	Poisson distribution (e.g., number of emails received per hour)
# •	Rolling a die
# 2. Continuous Distribution
# •	Deals with continuous random variables (uncountable, infinite values over an interval).
# •	Probabilities are assigned to intervals, not individual values.
# 🔹 Characteristics:
# •	Probability is given by a Probability Density Function (PDF).
# •	The probability of any single exact value is 0:
# P(X=a)=0 P(X = a) = 0 P(X=a)=0
# 🔹 Examples:
# •	Normal distribution (e.g., heights, IQ scores)
# •	Exponential distribution (e.g., time between arrivals)
# •	Uniform distribution (e.g., random number between 0 and 1)
#
#
# Question 4: What is a binomial distribution, and how is it used in probability?
#
#
# Answer:
#  A random variable XXX follows a binomial distribution if:
# •	The experiment consists of n independent trials.
# •	Each trial results in a success (with probability ppp) or a failure (with probability q=1−pq = 1 - pq=1−p).
# •	The probability of getting exactly k successes is given by the binomial formula:
# P(X=k)=(n ck )p^k(1−p)^n−k
# Where:
# •	(n c k)= number of combinations = n!/k!(n−k)!
# •	p = probability of success
# •	(1−p) = probability of failure
# •	k = number of successes
# •	n = number of trials
# Uses of Binomial Distribution:
# •	Quality control: Finding probability of defective items in a batch.
# •	Medical studies: Success rate of a treatment.
# •	Surveys and polling: Number of people supporting a candidate.
# •	Games and experiments: Coin tosses, dice rolls.
#
# Question 5: What is the standard normal distribution, and why is it important?
#
#
# Answer:
#  The standard normal distribution is a special case of the normal distribution with:
# •	Mean μ=0\mu = 0μ=0
# •	Standard deviation σ=1\sigma = 1σ=1
# It is represented by the random variable ZZZ, often called the Z-distribution.
# 🔹 Probability Density Function (PDF):
# f(z)=(e^-z^2/2)/(2 pi)^1/2
#
#
# Question 6: What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# Answer:
# The Central Limit Theorem is a fundamental principle in statistics that states:
# When independent random variables are added, their normalized sum tends toward a normal distribution, regardless of the original distribution, as the sample size becomes large.
#
#    Example:
# Suppose individual weights of apples follow a skewed distribution, but if you take the average weight of 50 apples repeatedly, the distribution of those averages will be approximately normal due to the CLT.
#
#
#
#
# Question 7: What is the significance of confidence intervals in statistical analysis?
# Answer:
#  A confidence interval (CI) is a range of values, derived from sample data, that is likely to contain the true population parameter (such as mean or proportion) with a certain level of confidence.
# Confidence Interval=Point Estimate±Margin of Error\text{Confidence Interval} = \text{Point Estimate} \pm \text{Margin of Error}Confidence Interval=Point Estimate±Margin of Error
# Significance of Confidence Intervals:
# 1.	Estimate population parameters:
# o	CIs provide a range in which the true value (mean, proportion, etc.) is likely to lie—not just a single number.
# 2.	Account for sampling variability:
# o	Since samples can vary, CIs express the uncertainty in estimates.
# 3.	Communicate reliability:
# o	A narrower interval = more precise estimate (usually from larger samples or less variability).
# o	A wider interval = less precise.
# 4.	Support decision-making:
# o	Helps determine statistical significance—e.g., if a CI for a difference excludes 0, it may imply a significant effect.
# 5.	Used in hypothesis testing:
# o	If a CI does not contain the null hypothesis value (e.g., mean = 0), the result is statistically significant at that confidence level.
#
# Question 8: What is the concept of expected value in a probability distribution?
# Answer:  The expected value (EV) of a random variable is the long-term average or mean value it would take if the experiment were repeated many times.
# It represents the center of a probability distribution.
# Expected Value=E(X)\text{Expected Value} = E(X)Expected Value=E(X)
# 1.	Predicts average outcome in the long run
# 2.	Used in:
# o	Decision-making (e.g., economics, finance)
# o	Game theory and gambling
# o	Insurance and risk assessment
# 3.	Helps compare different probabilistic scenarios

# %%
'''Question 9: Write a Python program to generate 1000 random numbers from a normal distribution with mean = 50 and standard deviation = 5. Compute its mean and standard deviation using NumPy, and draw a histogram to visualize the distribution. (Include your Python code and output in the code box below.)  '''

import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate 1000 random numbers from normal distribution
data = np.random.normal(loc=50, scale=5, size=1000)

# Step 2: Compute mean and standard deviation
mean = np.mean(data)
std_dev = np.std(data)

# Step 3: Print results
print(f"Mean of the generated data: {mean:.2f}")
print(f"Standard Deviation of the generated data: {std_dev:.2f}")

# Step 4: Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(data, bins=30, color='skyblue', edgecolor='black', density=True)
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Frequency Density')
plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean = {mean:.2f}')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Mean of the generated data: 49.96
# Standard Deviation of the generated data: 4.87
